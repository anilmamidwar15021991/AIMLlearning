# %% [markdown]
# # Assignment Set 2 - Bivariate Analysis

# %%
# import packages
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Q1. Find the pearson's correlation of all the numerical columns with Price column

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93.csv')
df.dropna(inplace = True)

#move price column to the last
temp_cols= df.columns.tolist()
new_cols_position= temp_cols[0:4]+temp_cols[5:]+temp_cols[4:5]
df=df[new_cols_position]
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Max.Price  MPG.city  MPG.highway  \
# 0        Acura  Integra    Small       12.9       18.8        25           31
# 1        Acura   Legend  Midsize       29.2       38.7        18           25
# 2         Audi       90  Compact       25.9       32.3        20           26
# 3         Audi      100  Midsize       30.8       44.6        19           26
# 4          BMW     535i  Midsize       23.7       36.2        22           30
#
#               AirBags DriveTrain Cylinders  ...  Length  Wheelbase  Width  \
# 0                None      Front         4  ...     177        102     68
# 1  Driver & Passenger      Front         6  ...     195        115     71
# 2         Driver only      Front         6  ...     180        102     67
# 3  Driver & Passenger      Front         6  ...     193        106     70
# 4         Driver only       Rear         4  ...     186        109     69
#
# ...

# %%
from scipy.stats import pearsonr

#calcaulting relation of all linear variable with price column using pearsonr method

def pearsonrCorr(x,Y):
    print('x column is ' + x)
    corr,_= pearsonr(df[x],df[Y])
    print(f' pearson correlation is {corr:.5f} and p-value is {_:.23f}')

# %%
for col in df.select_dtypes(include=np.number):
    pearsonrCorr(col,'Price')
# Out:
# x column is Min.Price
#  pearson correlation is 0.97135 and p-value is 0.00000000000000000000000
# x column is Max.Price
#  pearson correlation is 0.98264 and p-value is 0.00000000000000000000000
# x column is MPG.city
#  pearson correlation is -0.62157 and p-value is 0.00000000046162464647151
# x column is MPG.highway
#  pearson correlation is -0.62593 and p-value is 0.00000000032136483966084
# x column is EngineSize
#  pearson correlation is 0.64181 and p-value is 0.00000000008165140860738
# x column is Horsepower
#  pearson correlation is 0.78725 and p-value is 0.00000000000000000178585
# x column is RPM
#  pearson correlation is -0.03495 and p-value is 0.75525648908770859346617
# x column is Rev.per.mile
#  pearson correlation is -0.43702 and p-value is 0.00004043016108524767729
# x column is Fuel.tank.capacity
#  pearson correlation is 0.70728 and p-value is 0.00000000000011081647346
# x column is Passengers
# ...

# %% [markdown]
# ### Q2. Find all the statistically significane numerical columns affecting the Price of vehicle (use spearmanr correlation & significance level 0.05)

# %%
# Input
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93.csv')
df.dropna(inplace = True)
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0           31                None      Front  ...          5     177
# 1           25  Driver & Passenger      Front  ...          5     195
# 2           26         Driver only      Front  ...          5     180
# 3           26  Driver & Passenger      Front  ...          6     193
# 4           30         Driver only       Rear  ...          4     186
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
from scipy.stats import spearmanr
def corr_spearmanr(x,Y):
    corr, _ = spearmanr(df[x],df[Y])
    print(f' spearman correlation is  {corr:.3f} and p-value is  {_}')
          
          

for col in df.select_dtypes(include=np.number):
        print(col)
        corr_spearmanr(col,'Price')
# Out:
# Min.Price
#  spearman correlation is  0.975 and p-value is  3.267881519720848e-54
# Price
#  spearman correlation is  1.000 and p-value is  0.0
# Max.Price
#  spearman correlation is  0.986 and p-value is  1.9777782761178905e-64
# MPG.city
#  spearman correlation is  -0.830 and p-value is  5.957360047357504e-22
# MPG.highway
#  spearman correlation is  -0.777 and p-value is  1.0067306329409251e-17
# EngineSize
#  spearman correlation is  0.799 and p-value is  2.533146736346967e-19
# Horsepower
#  spearman correlation is  0.879 and p-value is  2.1567356930935557e-27
# RPM
#  spearman correlation is  -0.099 and p-value is  0.376987862332407
# Rev.per.mile
#  spearman correlation is  -0.587 and p-value is  7.036376762313768e-09
# Fuel.tank.capacity
#  spearman correlation is  0.840 and p-value is  6.255050271260672e-23
# Passengers
#  spearman correlation is  0.351 and p-value is  0.0012141945305695475
# Length
#  spearman correlation is  0.700 and p-value is  2.4944529027296525e-13
# ...

# %% [markdown]
# ### Q3. Find all the statistically significane categorical columns affecting the survival rate of tha passenger (use chi square test & significance level 0.05)

# %%
# Input
df = pd.read_csv('C:/Users/maste/Documents/Personal/ML+/Learning/Data preprocessing and EDA/Datasets_Course_Preprocessing_EDA/titanic.csv')
df.dropna(inplace = True)
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
from scipy.stats import chi2_contingency

print('this will give the observed frequency table')
for col in df.select_dtypes(exclude=np.number):
    print(col)
    observedfre= pd.crosstab(df[col],df['Survived'].astype('category'))
    stat,p,dof,expected = chi2_contingency(observedfre)
    print(f' chisquare value is {stat} and pvalue is {p} , dof is {dof}')
# Out:
# this will give the observed frequency table
# Name
#  chisquare value is 183.00000000000006 and pvalue is 0.4652345611198234 , dof is 182
# Sex
#  chisquare value is 49.62965365707783 and pvalue is 1.8568580662867508e-12 , dof is 1
# Ticket
#  chisquare value is 142.159756097561 and pvalue is 0.15409625260537252 , dof is 126
# Cabin
#  chisquare value is 139.8908536585366 and pvalue is 0.3025291209344876 , dof is 132
# Embarked
#  chisquare value is 2.182317720126803 and pvalue is 0.3358270915144236 , dof is 2

# %% [markdown]
# chi square confirms that only sex variable is statistically significant with Y variable rest all can be rejected

# %%
observedfre= pd.crosstab(df['Cabin'],df['Survived'].astype('category'))

observedfre
# Out:
# Survived  0  1
# Cabin
# A10       1  0
# A16       0  1
# A20       0  1
# A23       0  1
# A24       1  0
# ...      .. ..
# F2        1  2
# F33       0  3
# F4        0  2
# G6        2  2
# T         1  0
#
# [133 rows x 2 columns]

# %% [markdown]
# ### Q4. Find all the statistically significane numerical columns affecting the survival rate of tha passenger (use ANOVA & significance level 0.05)

# %%
# Input
import scipy.stats as stats
import matplotlib.pyplot as plt 

df.dropna(inplace = True)
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
#tke the ramdom sample for each group

sample_df = df[['Survived','Age']]
unique_survived = df['Survived'].unique()
for survied in unique_survived:
    stats.probplot(df[df['Survived']== survied]['Age'],plot=plt ,dist='norm')
    
    plt.show()

# %%
for survied in unique_survived:
    stats.probplot(df[df['Survived']==survied]['Parch'],plot=plt,dist='norm')
    
    plt.show()

# %%
#above Q-Q plot shows that only age variable samples has normal probability distribution

# %%
#we will check the anova significance using statsmodel api
import statsmodels.api as sm
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols

# %%
for numerical_col in df.select_dtypes(include=np.number):
    model=ols(numerical_col + '~ C(Survived)',df).fit()
    print(f' Overall model F for column {numerical_col} is ({model.df_model:.0f}, {model.df_resid:.0f})={model.fvalue:.3f}, p={model.f_pvalue:.4f}')
    res=sm.stats.anova_lm(model,typ=2)
res
# Out:
#  Overall model F for column PassengerId is (1, 181)=4.081, p=0.0448
#  Overall model F for column Survived is (1, 181)=12664125021947185463690355844055040.000, p=0.0000
#  Overall model F for column Pclass is (1, 181)=0.216, p=0.6425
#  Overall model F for column Age is (1, 181)=12.492, p=0.0005
#  Overall model F for column SibSp is (1, 181)=2.070, p=0.1519
#  Overall model F for column Parch is (1, 181)=0.101, p=0.7513
#  Overall model F for column Fare is (1, 181)=3.322, p=0.0700
#                    sum_sq     df         F    PR(>F)
# C(Survived)  1.911770e+04    1.0  3.321597  0.070026
# Residual     1.041759e+06  181.0       NaN       NaN
